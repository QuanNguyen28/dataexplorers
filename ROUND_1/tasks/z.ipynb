# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from dataflow import df_train, df_test, df_geography, df_product

# %% [markdown]
# # 1. Kiểm chứng các tính chất chuỗi thời gian

# %%
# Kết nối tự nhiên giữa các bảng
df = df_train.merge(df_geography, on='Zip', how='left').merge(df_product, on='ProductID', how='left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901561 entries, 0 to 901560
# Data columns (total 13 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ProductID  901561 non-null  int64
#  1   Date       901561 non-null  datetime64[ns]
#  2   Zip        901561 non-null  int64
#  3   Units      901561 non-null  int64
#  4   Revenue    901561 non-null  float64
#  5   COGS       901561 non-null  float64
#  6   City       901561 non-null  object
#  7   State      901561 non-null  object
#  8   Region     901561 non-null  object
#  9   District   901561 non-null  object
#  10  Category   901561 non-null  object
#  11  Segment    901561 non-null  object
#  12  Product    901561 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(7)
# memory usage: 89.4+ MB

# %% [markdown]
# ## 1.1. Trực quan hóa dữ liệu theo thời gian

# %%
# Gom nhóm theo tháng
df_monthly = df.groupby(pd.Grouper(key='Date', freq='MS')).agg({'Revenue': 'sum', 'Units': 'sum'}).reset_index()

# Vẽ biểu đồ xu hướng doanh thu theo thời gian
plt.figure(figsize=(12,6))
plt.plot(df_monthly['Date'], df_monthly['Revenue'], label='Doanh thu hàng tháng', color='blue')
plt.title("Xu hướng doanh thu theo thời gian")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.legend()
plt.show()

# %%
import seaborn as sns

# Gom nhóm theo tháng và vùng
df_region_monthly = df.groupby([pd.Grouper(key='Date', freq='MS'), 'Region']).agg({'Revenue': 'sum'}).reset_index()

# Vẽ biểu đồ xu hướng doanh thu theo từng vùng
plt.figure(figsize=(12,6))
sns.lineplot(data=df_region_monthly, x='Date', y='Revenue', hue='Region')
plt.title("Xu hướng doanh thu theo vùng")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.show()

# %% [markdown]
# ### a. Kiểm chứng hệ số tương quan Pearson

# %%
# Tạo bảng doanh thu theo từng vùng
df_pivot = df_region_monthly.pivot(index="Date", columns="Region", values="Revenue")

# Tính ma trận tương quan
corr_matrix = df_pivot.corr()

# Vẽ biểu đồ heatmap cho ma trận tương quan
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Ma trận tương quan doanh thu giữa các vùng")
plt.show()

# %% [markdown]
# - Biểu đồ heatmap thể hiện ma trận tương quan giữa các vùng Central, East, và West.
# - Hệ số tương quan giữa Central và East là 0.98, giữa East và West là 0.93, và giữa Central và West là 0.87.
# - Điều này chỉ ra rằng doanh thu giữa các vùng có mối liên hệ rất mạnh. Khi doanh thu ở một vùng tăng, doanh thu ở vùng khác cũng có xu hướng tăng theo.
# - Mối liên hệ mạnh như vậy có thể do các yếu tố tác động chung như xu hướng tiêu dùng theo mùa vụ, chính sách giá, hoặc chiến dịch marketing đồng nhất trên toàn quốc.
#
# ⏩ **Nhận xét:** Do mức tương quan quá cao, dự báo doanh thu của một vùng có thể hỗ trợ cho việc dự báo các vùng khác. Nếu ta có dữ liệu tốt của một vùng, có thể sử dụng để dự đoán vùng khác.

# %% [markdown]
# ### b. Kiểm chứng tương quan chéo

# %%
# Chọn các cặp vùng để kiểm tra cross-correlation
pairs = [('East', 'Central'), ('Central', 'West'), ('East', 'West')]

# Tạo figure với 3 subplot
fig, axes = plt.subplots(3, 1, figsize=(12, 12))

# Duyệt qua từng cặp vùng
for i, (region1, region2) in enumerate(pairs):
    series1 = df_pivot[region1].dropna()
    series2 = df_pivot[region2].dropna()
    
    # Kiểm tra và căn chỉnh độ dài chuỗi thời gian
    min_length = min(len(series1), len(series2))
    series1, series2 = series1.iloc[:min_length], series2.iloc[:min_length]

    # Tính cross-correlation
    lags = range(-12, 13)  # Xem xét độ trễ trong khoảng 12 tháng
    cross_corr = [series1.corr(series2.shift(lag)) for lag in lags]

    # Vẽ biểu đồ cross-correlation
    axes[i].bar(lags, cross_corr)
    axes[i].set_title(f"Cross-correlation giữa vùng {region1} và {region2}")
    axes[i].set_xlabel("Độ trễ (tháng)")
    axes[i].set_ylabel("Hệ số tương quan")
    axes[i].axhline(0, color='black', linestyle='--')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Biểu đồ cột thể hiện hệ số cross-correlation giữa doanh thu của các cặp vùng East-Central, Central-West, và East-West với độ trễ từ -12 đến 12 tháng.
# - Hệ số cao nhất (~1.0) xảy ra ở độ trễ = 0 tháng, nghĩa là hai vùng này có xu hướng thay đổi đồng thời.
# - Một số độ trễ dương (+1, +2, …) và âm (-1, -2, …) cũng có hệ số tương quan khá cao, điều này cho thấy đôi khi có thể có sự chậm trễ nhẹ về phản ứng doanh thu giữa các vùng, nhưng không đáng kể.
#
# ⏩ **Nhận xét:** Vì doanh thu ở các cặp vùng có biến động đồng thời, có thể dùng mô hình Vector AutoRegression (VAR) để dự báo hai vùng cùng lúc thay vì dự báo riêng lẻ.

# %% [markdown]
# ### c. Phân tích thành phần chính (PCA)

# %%
from sklearn.decomposition import PCA

# Chuẩn hóa dữ liệu
df_pivot_norm = (df_pivot - df_pivot.mean()) / df_pivot.std()

# Áp dụng PCA
pca = PCA(n_components=3)
pca.fit(df_pivot_norm.dropna())

# Vẽ biểu đồ tỷ lệ phương sai tích lũy
plt.figure(figsize=(8,5))
plt.plot(range(1, 4), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.xlabel("Số thành phần chính")
plt.ylabel("Tỷ lệ phương sai tích lũy")
plt.title("Phân tích thành phần chính (PCA)")
plt.show()

# Hiển thị trọng số của mỗi vùng trong thành phần chính đầu tiên
print("Trọng số của các vùng trong PC1:")
print(pca.components_[0])
# Out:
# Trọng số của các vùng trong PC1:
# [0.57710379 0.58820158 0.56654224]

# %% [markdown]
# Biểu đồ tỷ lệ phương sai tích lũy (explained variance ratio) cho thấy:
#
# - Thành phần chính đầu tiên (PC1) chiếm khoảng 95% phương sai, có nghĩa là gần như toàn bộ biến động doanh thu giữa các vùng có thể được giải thích chỉ bằng một yếu tố chính.
# - Thành phần chính thứ hai (PC2) nâng tổng tỷ lệ lên gần 100%, nghĩa là chỉ cần 2 thành phần chính là có thể tái tạo toàn bộ thông tin ban đầu.

# %% [markdown]
# ## 1.2. Kiểm tra tính dừng (Stationarity)

# %%
from statsmodels.tsa.stattools import adfuller

adf_result = adfuller(df_monthly['Revenue'])
print("ADF Statistic: %f" % adf_result[0])
print("p-value: %f" % adf_result[1])

if adf_result[1] > 0.05:
    print("Chuỗi không dừng")
else:
    print("Chuỗi dừng")
# Out:
# ADF Statistic: -0.603644
# p-value: 0.870156
# Chuỗi không dừng

# %%
df_monthly['Revenue_diff'] = df_monthly['Revenue'].diff()

# Kiểm định ADF sau khi lấy hiệu sai
adf_result_diff = adfuller(df_monthly['Revenue_diff'].dropna())
print("ADF Statistic after differencing: %f" % adf_result_diff[0])
print("p-value after differencing: %f" % adf_result_diff[1])

if adf_result_diff[1] > 0.05:
    print("Chuỗi vẫn không dừng, cần tiếp tục lấy hiệu sai")
else:
    print("Chuỗi đã dừng, có thể áp dụng mô hình dự báo")
# Out:
# ADF Statistic after differencing: -4.117726
# p-value after differencing: 0.000905
# Chuỗi đã dừng, có thể áp dụng mô hình dự báo

# %% [markdown]
# ## 1.3. Kiểm tra yếu tố mùa vụ (Seasonality)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Sử dụng seasonal_decompose với khoảng chu kỳ là 12 tháng
result = seasonal_decompose(df_monthly['Revenue'], model='additive', period=12)
result.plot()
plt.show()

# %% [markdown]
# Biểu đồ trên thể hiện kết quả phân rã doanh thu (Revenue) thành các thành phần chính:
#
# 1. Chuỗi gốc (Revenue): Doanh thu có dao động theo thời gian, với các biến động rõ ràng.
#
# 2. Xu hướng (Trend):
#
# - Tăng dần trong nửa đầu chuỗi → Có thể do thị trường mở rộng hoặc tăng trưởng tự nhiên.
# - Sau đó, xu hướng giảm xuống → Có thể do suy thoái kinh tế, thay đổi chính sách giá, hoặc mất thị phần.
#
# 3. Thành phần mùa vụ (Seasonal):
#
# - Có chu kỳ lặp lại ổn định theo từng giai đoạn → Điều này chỉ ra rằng doanh thu có tính mùa vụ rõ ràng.
# - Có thể liên quan đến kỳ nghỉ lễ, xu hướng tiêu dùng theo mùa.
#
# 4. Phần dư (Residual):
#
# - Các dao động ngẫu nhiên (nhiễu) không được giải thích bởi xu hướng hoặc mùa vụ.
# - Một số điểm có biên độ lớn → Có thể là do các sự kiện đột xuất như khuyến mãi lớn hoặc sự kiện bất ngờ.

# %%
# Kiểm định ADF trên phần dư
adf_test_resid = adfuller(result.resid.dropna())
print(f"ADF Statistic: {adf_test_resid[0]}")
print(f"p-value: {adf_test_resid[1]}")

if adf_test_resid[1] > 0.05:
    print("Phần dư chưa dừng, có thể cần tiếp tục xử lý")
else:
    print("Phần dư đã dừng, có thể sử dụng trong mô hình dự báo")
# Out:
# ADF Statistic: -5.134789329942951
# p-value: 1.1928189281943253e-05
# Phần dư đã dừng, có thể sử dụng trong mô hình dự báo

# %% [markdown]
# ## 1.4. Kiểm tra tự tương quan (ACF & PACF)

# %%
import statsmodels.api as sm

fig, ax = plt.subplots(2, 1, figsize=(12,8))

# Vẽ biểu đồ ACF (tự tương quan)
sm.graphics.tsa.plot_acf(df_monthly['Revenue_diff'].dropna(), lags=30, ax=ax[0])
ax[0].set_title("Autocorrelation (ACF)")

# Vẽ biểu đồ PACF (tự tương quan riêng phần)
sm.graphics.tsa.plot_pacf(df_monthly['Revenue_diff'].dropna(), lags=30, ax=ax[1])
ax[1].set_title("Partial Autocorrelation (PACF)")

plt.show()

# %% [markdown]
# * ACF và PACF đều có đỉnh cao nhất ở lag 12 → Chuỗi có tính mùa vụ hàng năm (12 tháng).
# * PACF có giá trị cao ở lag 12 → Mô hình có thể cần một thành phần autoregressive (AR) cho chu kỳ mùa vụ.

# %% [markdown]
# # 2. Xây dựng mô hình SARIMA

# %% [markdown]
# ## 2.1. Huấn luyện mô hình

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

df_monthly = df_monthly.set_index('Date')
df_monthly = df_monthly['Revenue']  # Chỉ lấy cột doanh thu

# Đảm bảo dữ liệu có tần suất tháng
df_monthly = df_monthly.asfreq('MS')

# %%
df_monthly.head()
# Out:
# Date
# 2010-07-01    36351952.56
# 2010-08-01    47303856.18
# 2010-09-01    34881766.29
# 2010-10-01    32132565.36
# 2010-11-01    27462497.58
# Freq: MS, Name: Revenue, dtype: float64

# %%
# Xây dựng mô hình SARIMA với tham số (p=1, d=1, q=1) và (P=1, D=1, Q=1, s=12)
sarima_model = SARIMAX(df_monthly, 
                        order=(1, 1, 1), 
                        seasonal_order=(1, 1, 1, 12), 
                        enforce_stationarity=False, 
                        enforce_invertibility=False)

# Huấn luyện mô hình
sarima_result = sarima_model.fit()

# In kết quả
print(sarima_result.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                            Revenue   No. Observations:                  126
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -1683.016
# Date:                            Fri, 21 Feb 2025   AIC                           3376.033
# Time:                                    21:01:22   BIC                           3389.008
# Sample:                                07-01-2010   HQIC                          3381.283
#                                      - 12-01-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4057      0.181     -2.237      0.025      -0.761      -0.050
# ma.L1         -0.0171      0.199     -0.086      0.932      -0.406       0.372
# ar.S.L12       0.3365      0.243      1.383      0.167      -0.140       0.814
# ma.S.L12      -0.5398      0.180     -2.994      0.003      -0.893      -0.186
# sigma2      3.566e+13   1.77e-15   2.01e+28      0.000    3.57e+13    3.57e+13
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.34
# Prob(Q):                              0.97   Prob(JB):                         0.31
# Heteroskedasticity (H):               0.26   Skew:                             0.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.61e+44. Standard errors may be unstable.

# %%
from pmdarima import auto_arima

# Chạy Auto ARIMA để tìm tham số tốt nhất
model_auto = auto_arima(df_monthly, seasonal=True, m=12, trace=True, suppress_warnings=True)
print(model_auto.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=4340.180, Time=0.37 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=4419.467, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=4350.753, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=4370.345, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=4417.488, Time=0.01 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=4354.978, Time=0.23 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=4338.549, Time=0.19 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=4392.074, Time=0.08 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=4340.217, Time=0.49 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=4342.178, Time=0.79 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=4339.644, Time=0.14 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=4338.857, Time=0.13 sec
#  ARIMA(3,1,2)(1,0,0)[12] intercept   : AIC=4336.995, Time=0.26 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=4376.693, Time=0.10 sec
#  ARIMA(3,1,2)(2,0,0)[12] intercept   : AIC=4338.642, Time=0.59 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=4338.623, Time=0.40 sec
#  ARIMA(3,1,2)(0,0,1)[12] intercept   : AIC=4347.999, Time=0.25 sec
#  ARIMA(3,1,2)(2,0,1)[12] intercept   : AIC=4340.623, Time=0.79 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=4338.072, Time=0.26 sec
#  ARIMA(4,1,2)(1,0,0)[12] intercept   : AIC=4316.363, Time=0.39 sec
#  ARIMA(4,1,2)(0,0,0)[12] intercept   : AIC=4373.258, Time=0.15 sec
#  ARIMA(4,1,2)(2,0,0)[12] intercept   : AIC=4318.030, Time=0.71 sec
#  ARIMA(4,1,2)(1,0,1)[12] intercept   : AIC=4318.029, Time=0.38 sec
#  ARIMA(4,1,2)(0,0,1)[12] intercept   : AIC=4331.303, Time=0.34 sec
#  ARIMA(4,1,2)(2,0,1)[12] intercept   : AIC=4320.027, Time=0.87 sec
#  ARIMA(4,1,1)(1,0,0)[12] intercept   : AIC=4339.840, Time=0.26 sec
#  ARIMA(5,1,2)(1,0,0)[12] intercept   : AIC=4316.234, Time=0.34 sec
#  ARIMA(5,1,2)(0,0,0)[12] intercept   : AIC=4346.094, Time=0.19 sec
#  ARIMA(5,1,2)(2,0,0)[12] intercept   : AIC=4317.808, Time=0.77 sec
#  ARIMA(5,1,2)(1,0,1)[12] intercept   : AIC=4317.801, Time=0.51 sec
#  ARIMA(5,1,2)(0,0,1)[12] intercept   : AIC=4325.270, Time=0.34 sec
#  ARIMA(5,1,2)(2,0,1)[12] intercept   : AIC=4319.797, Time=1.01 sec
#  ARIMA(5,1,1)(1,0,0)[12] intercept   : AIC=4328.134, Time=0.25 sec
#  ARIMA(5,1,3)(1,0,0)[12] intercept   : AIC=4307.552, Time=0.52 sec
#  ARIMA(5,1,3)(0,0,0)[12] intercept   : AIC=4338.155, Time=0.34 sec
#  ARIMA(5,1,3)(2,0,0)[12] intercept   : AIC=4309.048, Time=1.25 sec
#  ARIMA(5,1,3)(1,0,1)[12] intercept   : AIC=4309.311, Time=0.72 sec
#  ARIMA(5,1,3)(0,0,1)[12] intercept   : AIC=4314.234, Time=0.76 sec
#  ARIMA(5,1,3)(2,0,1)[12] intercept   : AIC=inf, Time=1.48 sec
#  ARIMA(4,1,3)(1,0,0)[12] intercept   : AIC=4326.689, Time=0.52 sec
#  ARIMA(5,1,4)(1,0,0)[12] intercept   : AIC=inf, Time=0.88 sec
#  ARIMA(4,1,4)(1,0,0)[12] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(5,1,3)(1,0,0)[12]             : AIC=4304.532, Time=0.57 sec
#  ARIMA(5,1,3)(0,0,0)[12]             : AIC=4333.899, Time=0.31 sec
#  ARIMA(5,1,3)(2,0,0)[12]             : AIC=4306.017, Time=0.95 sec
#  ARIMA(5,1,3)(1,0,1)[12]             : AIC=4305.866, Time=0.63 sec
#  ARIMA(5,1,3)(0,0,1)[12]             : AIC=4310.734, Time=0.68 sec
#  ARIMA(5,1,3)(2,0,1)[12]             : AIC=4307.662, Time=1.41 sec
#  ARIMA(4,1,3)(1,0,0)[12]             : AIC=4323.243, Time=0.52 sec
#  ARIMA(5,1,2)(1,0,0)[12]             : AIC=4313.810, Time=0.38 sec
#  ARIMA(5,1,4)(1,0,0)[12]             : AIC=4301.270, Time=0.72 sec
#  ARIMA(5,1,4)(0,0,0)[12]             : AIC=4348.314, Time=0.34 sec
#  ARIMA(5,1,4)(2,0,0)[12]             : AIC=4302.897, Time=1.54 sec
#  ARIMA(5,1,4)(1,0,1)[12]             : AIC=4301.741, Time=0.74 sec
#  ARIMA(5,1,4)(0,0,1)[12]             : AIC=4307.170, Time=0.71 sec
#  ARIMA(5,1,4)(2,0,1)[12]             : AIC=4303.307, Time=1.58 sec
#  ARIMA(4,1,4)(1,0,0)[12]             : AIC=4323.793, Time=0.62 sec
#  ARIMA(5,1,5)(1,0,0)[12]             : AIC=inf, Time=0.82 sec
#  ARIMA(4,1,5)(1,0,0)[12]             : AIC=inf, Time=0.62 sec
#
# Best model:  ARIMA(5,1,4)(1,0,0)[12]
# Total fit time: 32.075 seconds
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  126
# Model:             SARIMAX(5, 1, 4)x(1, 0, [], 12)   Log Likelihood               -2139.635
# Date:                             Fri, 21 Feb 2025   AIC                           4301.270
# Time:                                     21:01:54   BIC                           4332.382
# Sample:                                 07-01-2010   HQIC                          4313.909
#                                       - 12-01-2020
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1398      0.175     -0.798      0.425      -0.483       0.204
# ar.L2          0.8381      0.125      6.693      0.000       0.593       1.084
# ar.L3          0.1783      0.173      1.029      0.303      -0.161       0.518
# ar.L4         -0.8135      0.122     -6.666      0.000      -1.053      -0.574
# ar.L5         -0.2505      0.100     -2.506      0.012      -0.446      -0.055
# ma.L1         -0.0543      0.156     -0.349      0.727      -0.359       0.251
# ma.L2         -0.8096      0.124     -6.504      0.000      -1.054      -0.566
# ma.L3         -0.1037      0.124     -0.833      0.405      -0.348       0.140
# ma.L4          0.8555      0.117      7.287      0.000       0.625       1.086
# ar.S.L12       0.6673      0.050     13.447      0.000       0.570       0.765
# sigma2      4.409e+13   2.35e-15   1.87e+28      0.000    4.41e+13    4.41e+13
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                19.86
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.26   Skew:                            -0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.55e+44. Standard errors may be unstable.

# %% [markdown]
# ## 2.2. Đánh giá mô hình

# %%
df_test_monthly = df_test.groupby(pd.Grouper(key='Date', freq='MS')).agg({'Revenue': 'sum'}).reset_index()

# Sắp xếp lại dữ liệu theo thời gian
df_test_monthly = df_test_monthly.set_index('Date')

df_test_monthly.head()
# Out:
#                 Revenue
# Date
# 2021-01-01  17404126.74
# 2021-02-01  22244195.61
# 2021-03-01  32252658.48
# 2021-04-01  42042708.54
# 2021-05-01  44448474.42

# %%
len(df_test_monthly)
# Out:
# 19

# %%
# Ngày đầu tiên và cuối cùng trong tập test
df_test['Date'].min(), df_test['Date'].max()
# Out:
# (Timestamp('2021-01-01 00:00:00'), Timestamp('2022-07-01 00:00:00'))

# %%
df_test = df_test.sort_values('Date')

# %%
# Vẽ toàn bộ đường dự báo bởi mô hình trên tập train
plt.figure(figsize=(12,6))
plt.plot(df_monthly, label='Doanh thu thực tế')
plt.plot(sarima_result.predict(start=df_monthly.index[0], end=df_monthly.index[-1]), label='Dự báo trên tập train')
plt.title("Dự báo doanh thu trên tập train")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.legend()
plt.show()

# %%
# Vẽ dự đoán của model_auto trên tập train
plt.figure(figsize=(12,6))
plt.plot(df_monthly, label='Doanh thu thực tế')
plt.plot(model_auto.predict_in_sample(), label='Dự báo trên tập train')
plt.title("Dự báo doanh thu trên tập train")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.legend()
plt.show()

# %%
# Dự báo doanh thu
forecast = model_auto.predict(n_periods=len(df_test_monthly))

# Tạo dataframe chứa dữ liệu dự báo
df_forecast = pd.DataFrame(forecast, index=df_test_monthly.index, columns=['Forecast'])

# Kết hợp dữ liệu thực tế và dự báo
df_compare = df_test_monthly.join(df_forecast)

# Vẽ biểu đồ dự báo
plt.figure(figsize=(12,6))

plt.plot(df_compare.index, df_compare['Revenue'], label='Doanh thu thực tế', color='blue')
plt.plot(df_compare.index, df_compare['Forecast'], label='Dự báo', color='red', linestyle='--')

plt.title("Dự báo doanh thu")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.legend()
plt.show()

# %%
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error
import numpy as np

# Lấy giá trị thực tế và giá trị dự báo
y_true = df_compare['Revenue'].dropna()
y_pred = df_compare['Forecast'].dropna()

# Tính các độ đo
r2 = r2_score(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred) * 100  # Convert to %
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# Hiển thị kết quả
print(f"R-squared: {r2:.4f}")
print(f"MAPE: {mape:.2f}%")
print(f"RMSE: {rmse:.2f}")
# Out:
# R-squared: 0.5589
# MAPE: 36.25%
# RMSE: 8094308.66

# %%
residuals = y_true - y_pred

# Vẽ biểu đồ phần dư
plt.figure(figsize=(12,6))
plt.plot(residuals, marker='o', linestyle='None', color='red')
plt.axhline(y=0, color='black', linestyle='--')
plt.title("Phần dư của mô hình SARIMA")
plt.xlabel("Thời gian")
plt.ylabel("Sai số dự báo")
plt.show()

# %% [markdown]
# # 3. Xây dựng mô hình Prophet

# %% [markdown]
# ## 3.1. Huấn luyện mô hình

# %%
from prophet import Prophet

# Chuẩn bị dữ liệu cho Prophet
df_prophet = df_monthly.reset_index().rename(columns={'Date': 'ds', 'Revenue': 'y'})

# Khởi tạo mô hình Prophet
model_prophet = Prophet(seasonality_mode='multiplicative', yearly_seasonality=True)
model_prophet.fit(df_prophet)

# Dự báo trên độ dài của df_test_monthly (tập test)
future = model_prophet.make_future_dataframe(periods=len(df_test_monthly), freq='MS')
forecast_prophet = model_prophet.predict(future)

# Vẽ biểu đồ dự báo
model_prophet.plot(forecast_prophet)
plt.title("Dự báo doanh thu bằng Prophet")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.show()
# Out:
# 21:01:55 - cmdstanpy - INFO - Chain [1] start processing
# 21:01:55 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# ## 3.2. Đánh giá mô hình

# %%
# Lấy phần dự báo trùng với tập test
forecast_prophet = forecast_prophet.set_index('ds')
df_forecast = forecast_prophet[['yhat']].loc[df_test_monthly.index]

# Kết hợp với tập test
df_compare_prophet = df_test_monthly.join(df_forecast)
df_compare_prophet.rename(columns={'yhat': 'Forecast'}, inplace=True)

# %%
# Vẽ biểu đồ dự báo trên toàn bộ thời gian
plt.figure(figsize=(12,6))

# Vẽ tập train (dữ liệu gốc)
plt.plot(df_monthly.index, df_monthly, label='Tập Train (Thực tế)', color='blue')

# Vẽ tập test (dữ liệu thực tế trong khoảng dự báo)
plt.plot(df_test_monthly.index, df_test_monthly, label='Tập Test (Thực tế)', color='green')

# Vẽ dữ liệu dự báo từ Prophet trên toàn bộ phạm vi thời gian
plt.plot(forecast_prophet.index, forecast_prophet['yhat'], label='Dự báo Prophet', color='red', linestyle='--')

plt.title("Dự báo doanh thu bằng Prophet trên toàn bộ thời gian")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.legend()
plt.show()

# %%
# Lấy giá trị thực tế và dự báo
y_true = df_compare_prophet['Revenue'].dropna()
y_pred = df_compare_prophet['Forecast'].dropna()

# Tính các độ đo
r2_prophet = r2_score(y_true, y_pred)
mape_prophet = mean_absolute_percentage_error(y_true, y_pred) * 100  # Convert to %
rmse_prophet = np.sqrt(mean_squared_error(y_true, y_pred))

# Hiển thị kết quả
print(f"Prophet - R-squared: {r2_prophet:.4f}")
print(f"Prophet - MAPE: {mape_prophet:.2f}%")
print(f"Prophet - RMSE: {rmse_prophet:.2f}")
# Out:
# Prophet - R-squared: 0.5249
# Prophet - MAPE: 40.41%
# Prophet - RMSE: 8400599.31

# %% [markdown]
# # 4. Xây dựng mô hình XGBoost

# %% [markdown]
# ## 4.1. Huấn luyện mô hình

# %%
from xgboost import XGBRegressor

# Tạo đặc trưng thời gian
df_train_ml = df_monthly.reset_index()
df_train_ml['Year'] = df_train_ml['Date'].dt.year
df_train_ml['Month'] = df_train_ml['Date'].dt.month
df_train_ml['Quarter'] = df_train_ml['Date'].dt.quarter
df_train_ml['Lag_1'] = df_train_ml['Revenue'].shift(1)  # Độ trễ 1 tháng
df_train_ml = df_train_ml.dropna()

# Chuẩn bị dữ liệu tập test
df_test_ml = df_test_monthly.reset_index()
df_test_ml['Year'] = df_test_ml['Date'].dt.year
df_test_ml['Month'] = df_test_ml['Date'].dt.month
df_test_ml['Quarter'] = df_test_ml['Date'].dt.quarter
df_test_ml['Lag_1'] = df_monthly.iloc[-1]  # Dùng giá trị cuối cùng của train làm Lag_1 cho test
df_test_ml = df_test_ml.dropna()

# %%
# Huấn luyện mô hình
X_train = df_train_ml[['Year', 'Month', 'Quarter', 'Lag_1']]
y_train = df_train_ml['Revenue']
X_test = df_test_ml[['Year', 'Month', 'Quarter', 'Lag_1']]

model_xgb = XGBRegressor(n_estimators=100, learning_rate=0.01)
model_xgb.fit(X_train, y_train)

# Dự báo trên tập train
df_train_ml['Forecast'] = model_xgb.predict(X_train)

# Kết hợp với tập test
df_test_ml['Forecast'] = model_xgb.predict(X_test)

# %% [markdown]
# ## 4.2. Đánh giá mô hình

# %%
plt.figure(figsize=(12,6))

# Vẽ tập train (thực tế)
plt.plot(df_monthly.index, df_monthly, label="Tập Train (Thực tế)", color="blue")

# Vẽ tập test (thực tế)
plt.plot(df_test_monthly.index, df_test_monthly, label="Tập Test (Thực tế)", color="green")

# Vẽ dự báo trên tập train
plt.plot(df_train_ml['Date'], df_train_ml['Forecast'], label="Dự báo Train (XGBoost)", color="orange", linestyle="--")

# Vẽ dự báo trên tập test
plt.plot(df_test_monthly.index, df_test_ml['Forecast'], label="Dự báo Test (XGBoost)", color="red", linestyle="--")

plt.title("Dự báo doanh thu bằng XGBoost trên cả tập train & test")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.legend()
plt.show()

# %%
# Đánh giá trên tập train
y_true_train = df_train_ml['Revenue']
y_pred_train = df_train_ml['Forecast']

r2_train = r2_score(y_true_train, y_pred_train)
mape_train = mean_absolute_percentage_error(y_true_train, y_pred_train) * 100
rmse_train = np.sqrt(mean_squared_error(y_true_train, y_pred_train))

print(f"XGBoost Train - R-squared: {r2_train:.4f}")
print(f"XGBoost Train - MAPE: {mape_train:.2f}%")
print(f"XGBoost Train - RMSE: {rmse_train:.2f}")

# Đánh giá trên tập test
y_true_test = df_test_monthly['Revenue']
y_pred_test = df_test_ml['Forecast']

r2_test = r2_score(y_true_test, y_pred_test)
mape_test = mean_absolute_percentage_error(y_true_test, y_pred_test) * 100
rmse_test = np.sqrt(mean_squared_error(y_true_test, y_pred_test))

print(f"XGBoost Test - R-squared: {r2_test:.4f}")
print(f"XGBoost Test - MAPE: {mape_test:.2f}%")
print(f"XGBoost Test - RMSE: {rmse_test:.2f}")
# Out:
# XGBoost Train - R-squared: 0.8002
# XGBoost Train - MAPE: 18.22%
# XGBoost Train - RMSE: 7782759.39
# XGBoost Test - R-squared: -0.1005
# XGBoost Test - MAPE: 50.81%
# XGBoost Test - RMSE: 12785256.11

# %% [markdown]
# # 5. Xây dựng mô hình Holt-Winters (ETS)

# %% [markdown]
# ## 5.1. Huấn luyện mô hình

# %%
from statsmodels.tsa.statespace.structural import UnobservedComponents

# Khởi tạo mô hình UCM (Bayesian Structural Time Series)
model_ucm = UnobservedComponents(df_monthly, level='local linear trend', seasonal=12)
ucm_fit = model_ucm.fit()

# Dự báo trên tập test
df_test_monthly['Forecast'] = ucm_fit.forecast(len(df_test_monthly))

# %%
# Dự báo trên tập train
df_train_ucm = df_monthly.to_frame(name='Revenue')

df_train_ucm['Forecast'] = ucm_fit.fittedvalues

# %%
plt.figure(figsize=(12,6))

# Vẽ tập train (thực tế)
plt.plot(df_monthly.index, df_monthly, label="Tập Train (Thực tế)", color="blue")

# Vẽ tập test (thực tế)
plt.plot(df_test_monthly.index, df_test_monthly, label="Tập Test (Thực tế)", color="green")

# Vẽ dự báo trên tập train 
plt.plot(df_train_ucm.index, df_train_ucm['Forecast'], label="Dự báo Train (UCM)", color="orange", linestyle="--")

# Vẽ dự báo trên tập test
plt.plot(df_test_monthly.index, df_test_monthly['Forecast'], label="Dự báo Test (UCM)", color="red", linestyle="--")

plt.title("Dự báo doanh thu bằng BSTS (UCM) trên cả tập train & test")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.legend()
plt.show()

# %%
# Vẽ riêng dự báo trên tập test
plt.figure(figsize=(12,6))

# Vẽ tập test (thực tế)
plt.plot(df_test_monthly.index, df_test_monthly['Revenue'], label="Tập Test (Thực tế)", color="green")

# Vẽ dự báo trên tập test
plt.plot(df_test_monthly.index, df_test_monthly['Forecast'], label="Dự báo Test (UCM)", color="red", linestyle="--")

plt.title("Dự báo doanh thu bằng BSTS (UCM) trên tập test")
plt.xlabel("Thời gian")
plt.ylabel("Doanh thu")
plt.legend()
plt.show()

# %%
# Đánh giá trên tập test
y_true_test = df_test_monthly['Revenue']
y_pred_test = df_test_monthly['Forecast']

r2_ucm_test = r2_score(y_true_test, y_pred_test)
mape_ucm_test = mean_absolute_percentage_error(y_true_test, y_pred_test) * 100
rmse_ucm_test = np.sqrt(mean_squared_error(y_true_test, y_pred_test))

print(f"BSTS (UCM) Test - R-squared: {r2_ucm_test:.4f}")
print(f"BSTS (UCM) Test - MAPE: {mape_ucm_test:.2f}%")
print(f"BSTS (UCM) Test - RMSE: {rmse_ucm_test:.2f}")
# Out:
# BSTS (UCM) Test - R-squared: 0.5972
# BSTS (UCM) Test - MAPE: 38.75%
# BSTS (UCM) Test - RMSE: 7735224.28
