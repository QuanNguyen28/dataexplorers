# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_percentage_error, mean_squared_error


from loader import train_loader, val_loader, test_loader, scaler, df_train
from models.tcn import TemporalConvolutionalNetwork

# %%
print(torch.cuda.is_available())      # True nếu có GPU
print(torch.cuda.device_count())      # Số lượng GPU có thể sử dụng
print(torch.cuda.get_device_name(0))  # Tên của GPU
# Out:
# True
# 1
# NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %%
model = TemporalConvolutionalNetwork(
	seq_input_dim=2,  # "Units" và "Revenue"
	cal_input_dim=18, # Số lượng cột dữ liệu cần tính toán
	d_model=64, 
	nhead=4, 
	num_layers=2, 
	tcn_channels=[64, 64, 64],
	kernel_size=3, 
	dropout=0.1, 
	output_dim=2,
)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
# Cấu hình optimizer, loss, scheduler
criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

# %%
num_epochs = 100  # Bạn có thể tăng số epoch nếu cần
best_val_loss = float('inf')
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for x_seq, x_cal, y in train_loader:
        x_seq = x_seq.to(device)
        x_cal = x_cal.to(device)
        y = y.to(device)
        
        optimizer.zero_grad()
        outputs = model(x_seq, x_cal)
        loss = criterion(outputs, y)
        loss.backward()
        
        # Áp dụng gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        running_loss += loss.item() * x_seq.size(0)
    epoch_train_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_train_loss)
    
    model.eval()
    running_val_loss = 0.0
    with torch.no_grad():
        for x_seq, x_cal, y in val_loader:
            x_seq = x_seq.to(device)
            x_cal = x_cal.to(device)
            y = y.to(device)
            outputs = model(x_seq, x_cal)
            loss = criterion(outputs, y)
            running_val_loss += loss.item() * x_seq.size(0)
    epoch_val_loss = running_val_loss / len(val_loader.dataset)
    val_losses.append(epoch_val_loss)
    
    scheduler.step(epoch_val_loss)
    if (epoch + 1) % 10 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {epoch_train_loss:.4f}, Val Loss: {epoch_val_loss:.4f}")
    
    if epoch_val_loss < best_val_loss:
        best_val_loss = epoch_val_loss
        checkpoint = {
            'epoch': epoch+1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_loss': epoch_val_loss,
        }
        torch.save(checkpoint, 'checkpoints/TCN.pth')
        print(f"Best model updated at epoch {epoch+1} with validation loss {epoch_val_loss:.4f}")
# Out:
# Best model updated at epoch 1 with validation loss 0.1655
# Best model updated at epoch 3 with validation loss 0.1578
# Best model updated at epoch 4 with validation loss 0.1526
# Best model updated at epoch 5 with validation loss 0.1480
# Best model updated at epoch 7 with validation loss 0.1401
# Best model updated at epoch 8 with validation loss 0.1308
# Best model updated at epoch 9 with validation loss 0.0972
# Epoch [10/100], Train Loss: 0.0836, Val Loss: 0.0881
# Best model updated at epoch 10 with validation loss 0.0881
# Best model updated at epoch 11 with validation loss 0.0797
# Best model updated at epoch 12 with validation loss 0.0686
# Best model updated at epoch 13 with validation loss 0.0593
# Best model updated at epoch 15 with validation loss 0.0507
# Best model updated at epoch 17 with validation loss 0.0467
# Best model updated at epoch 18 with validation loss 0.0416
# Epoch [20/100], Train Loss: 0.0380, Val Loss: 0.0622
# Best model updated at epoch 21 with validation loss 0.0395
# Best model updated at epoch 22 with validation loss 0.0367
# Best model updated at epoch 25 with validation loss 0.0350
# Best model updated at epoch 27 with validation loss 0.0344
# Epoch [30/100], Train Loss: 0.0318, Val Loss: 0.0364
# Best model updated at epoch 31 with validation loss 0.0325
# Best model updated at epoch 32 with validation loss 0.0311
# Best model updated at epoch 34 with validation loss 0.0308
# Best model updated at epoch 35 with validation loss 0.0305
# Best model updated at epoch 36 with validation loss 0.0291
# Epoch [40/100], Train Loss: 0.0275, Val Loss: 0.0279
# Best model updated at epoch 40 with validation loss 0.0279
# Best model updated at epoch 41 with validation loss 0.0274
# Best model updated at epoch 42 with validation loss 0.0261
# Best model updated at epoch 47 with validation loss 0.0235
# Best model updated at epoch 48 with validation loss 0.0235
# Epoch [50/100], Train Loss: 0.0205, Val Loss: 0.0226
# Best model updated at epoch 50 with validation loss 0.0226
# Best model updated at epoch 51 with validation loss 0.0206
# Best model updated at epoch 54 with validation loss 0.0188
# Epoch [60/100], Train Loss: 0.0157, Val Loss: 0.0193
# Best model updated at epoch 67 with validation loss 0.0185
# Epoch [70/100], Train Loss: 0.0144, Val Loss: 0.0183
# Best model updated at epoch 70 with validation loss 0.0183
# Best model updated at epoch 71 with validation loss 0.0182
# Epoch [80/100], Train Loss: 0.0141, Val Loss: 0.0188
# Epoch [90/100], Train Loss: 0.0137, Val Loss: 0.0184
# Epoch [100/100], Train Loss: 0.0137, Val Loss: 0.0183

# %%
# Vẽ đồ thị loss
plt.figure(figsize=(14, 6))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.show()

# %%
# Load lại mô hình tốt nhất
checkpoint = torch.load('checkpoints/TCN.pth', map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
print(f"Best model loaded with validation loss: {checkpoint['val_loss']:.4f}")
# Out:
# Best model loaded with validation loss: 0.0182

# %%
def get_predictions(loader, model, device):
    model.eval()
    preds = []
    actuals = []
    with torch.no_grad():
        for x_seq, x_cal, y in loader:
            x_seq = x_seq.to(device)
            x_cal = x_cal.to(device)
            outputs = model(x_seq, x_cal)
            preds.append(outputs.cpu().numpy())
            actuals.append(y.numpy())
    preds = np.concatenate(preds, axis=0)
    actuals = np.concatenate(actuals, axis=0)
    return preds, actuals

# %%
# Dự báo trên tập train và test
train_preds, train_actuals = get_predictions(train_loader, model, device)
test_preds, test_actuals = get_predictions(test_loader, model, device)

# Inverse transform để đưa về thang đo ban đầu
train_preds_inv = scaler.inverse_transform(train_preds)
train_actuals_inv = scaler.inverse_transform(train_actuals)
test_preds_inv = scaler.inverse_transform(test_preds)
test_actuals_inv = scaler.inverse_transform(test_actuals)

# Tính các chỉ số đánh giá trên tập test
r2 = r2_score(test_actuals_inv, test_preds_inv)
mape = mean_absolute_percentage_error(test_actuals_inv, test_preds_inv)
rmse = np.sqrt(mean_squared_error(test_actuals_inv, test_preds_inv))
print(f"Test R-squared: {r2:.4f}")
print(f"Test MAPE: {mape:.4f}")
print(f"Test RMSE: {rmse:.4f}")
# Out:
# Test R-squared: 0.9507
# Test MAPE: 0.4439
# Test RMSE: 168875.8281

# %%
# Tính các chỉ số riêng cho Units và Revenue
r2_units = r2_score(test_actuals_inv[:, 0], test_preds_inv[:, 0])
mape_units = mean_absolute_percentage_error(test_actuals_inv[:, 0], test_preds_inv[:, 0])
rmse_units = np.sqrt(mean_squared_error(test_actuals_inv[:, 0], test_preds_inv[:, 0]))

print(f"Test Units R-squared: {r2_units:.4f}")
print(f"Test Units MAPE: {mape_units:.4f}")
print(f"Test Units RMSE: {rmse_units:.4f}")

r2_revenue = r2_score(test_actuals_inv[:, 1], test_preds_inv[:, 1])
mape_revenue = mean_absolute_percentage_error(test_actuals_inv[:, 1], test_preds_inv[:, 1])
rmse_revenue = np.sqrt(mean_squared_error(test_actuals_inv[:, 1], test_preds_inv[:, 1]))

print(f"Test Revenue R-squared: {r2_revenue:.4f}")
print(f"Test Revenue MAPE: {mape_revenue:.4f}")
print(f"Test Revenue RMSE: {rmse_revenue:.4f}")
# Out:
# Test Units R-squared: 0.9564
# Test Units MAPE: 0.5260
# Test Units RMSE: 27.0090
# Test Revenue R-squared: 0.9451
# Test Revenue MAPE: 0.3617
# Test Revenue RMSE: 238826.5156

# %%
# Vẽ đồ thị dự báo và thực tế đối với Units
plt.figure(figsize=(14, 6))
plt.plot(test_actuals_inv[:, 0], label='Actual')
plt.plot(test_preds_inv[:, 0], label='Predicted')
plt.title('Test Actual vs Predicted Units')
plt.legend()
plt.show()

# %%
# Vẽ đồ thị dự báo và thực tế đối với Revenue
plt.figure(figsize=(14, 6))
plt.plot(test_actuals_inv[:, 1], label='Actual')
plt.plot(test_preds_inv[:, 1], label='Predicted')
plt.title('Test Actual vs Predicted Revenue')
plt.legend()
plt.show()
